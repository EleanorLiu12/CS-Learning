# %% [markdown]
# < />: self-closing tags

# %% [markdown]
# < meta >: important info

# %% [markdown]
# < li >: list

# %% [markdown]
# < ul >: unordered list

# %% [markdown]
# < ol >: ordered list

# %% [markdown]
# < a href="link">: add link

# %% [markdown]
# < !-- comment-- >: comment in html
